# %%
# library import

import pandas as pd
import seaborn as sn

# %%
# leitura dos dados
url = "https://raw.githubusercontent.com/romariocsilva/MDCM/main/Data.csv"
data = pd.read_csv(url)
print(data)
# Out:
#         DH    PIB PC  IDHM     ES   ESA
# 0  2512.20  15201.46  0.72   64.0  55.1
# 1    96.65  58550.40  0.66   32.0  27.8
# 2  1230.25  20562.10  0.75  168.0  67.9
# 3   338.44  26267.84  0.67   17.0  17.4
# 4   187.21  21123.00  0.67   53.0  36.1
# 5  1071.15  15577.00  0.68   21.0  18.8
# 6    75.81  10196.64  0.63    9.0  10.6
# 7   102.11  11242.00  0.66   18.0  10.7

# %%
# análise de correlação

correlation = data.corr(method='pearson')

# plot da matriz de correlação

plot = sn.heatmap(correlation, annot = True, fmt=".1f", linewidths=.8)
plot
# Out:
# <Axes: >
